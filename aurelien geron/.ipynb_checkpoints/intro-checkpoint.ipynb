# %% [markdown]
# **How would you define machine learning?**
#
# Machine learning is training computer to perform a task without explicitly programming it for the task
#
# *A computer program is said to be learning from experience E, with respect to some task T with a performance measure P, if its performace on task T, as measured with P improves with experience E.*
#
# **Can you name 4 problems where it shines**
#
# 1. Marking Emails as 'spam' or 'ham'
# 2. Recognising objects
# 3. Speech recognition engines
# 4. Financial modelling
#
# **What is a labeled training set?**
#
# A labeled training set has a column with labels that is fed to algorithm for classifying data on the basis of label.
# Labeled training set are usually used in Supervised Learning.
#
# **What are the two most common supervised tasks?**
#
# Predicting stocks value
# Classification of data
#
# **Can you name four unsupervised tasks**
#
# Finding new patterns in data
# Making clusters that weren't visible at first
# Anomaly detection
# Reducing features from dataset(dimesionality reduction)
#
# **	What	type	of	Machine	Learning	algorithm	would	you	use	to	allow	a	robot	to	walk	in	various unknown	terrains? **
#
# Reinforcement Learning
#
# **	What	type	of	Machine	Learning	algorithm	would	you	use	to	allow	a	robot	to	walk	in	various unknown	terrains? **
#
# Classification or clustering
#
# **	Would	you	frame	the	problem	of	spam	detection	as	a	supervised	learning	problem	or	an unsupervised	learning	problem? **
#
# Unsupervised learning problem
#
# **What	is	an	online	learning	system? **
#
# When data is fed to machine in batches
#
# **What	is	out-of-core	learning? **
#
# When we use online training on machines that cannot fit the dataset
#
# **	What	type	of	learning	algorithm	relies	on	a	similarity	measure	to	make	predictions?**
#
# Instance based learning
#
# **	What	is	the	difference	between	a	model	parameter	and	a	learning	algorithm’s	hyperparameter? **
#
# Algorithm's hyperparameter affects the accuracy of the model like degee of freedom
#
# **What	do	model-based	learning	algorithms	search	for?	What	is	the	most	common	strategy	they	use to	succeed?	How	do	they	make	predictions? **
#
# They tweak hyperparameters till they are most accurately modeling the data
#
# **Can	you	name	four	of	the	main	challenges	in	Machine	Learning?**
#
#   Insufficient Quantity of training data
#     Non representative training data
#     Poor quality data
#     Irrelevant Featuers
#     Overfitting
#     Underfitting
#
# **If	your	model	performs	great	on	the	training	data	but	generalizes	poorly	to	new	instances,	what	is happening?	Can	you	name	three	possible	solutions?**
#
# Possibly the model is overfitted to the training data
#
# 1. Use cross-validation splitting of test and training data
# 2. Tweak hyperparameters on the validation set
# 3. Try using a simpler model
#
# **	What	is	a	test	set	and	why	would	you	want	to	use	it? **
#
# To ensure the model works well when introduced to new data on production
#
# **What	is	the	purpose	of	a	validation	set? **
#
# To tweak hyperparametes and avoid overfitment
#
# **What	can	go	wrong	if	you	tune	hyperparameters	using	the	test	set? **
#
# Model can overfit the test set
#
# **	What	is	cross-validation	and	why	would	you	prefer	it	to	a	validation	set?**
#
# It selects data randomly and not much of training data is lost on validation set
